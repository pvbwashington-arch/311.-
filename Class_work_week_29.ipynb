# %% [markdown]
# <a href="https://colab.research.google.com/github/pvbwashington-arch/311.-/blob/main/Class_work_week_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# start

# %%
# !pip install pandas
# !pip install matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# loaded file

# %%
df=pd.read_csv('https://raw.githubusercontent.com/pvbwashington-arch/311.-/refs/heads/main/311_Service_Requests_from_2019May.csv')
# Out:
# /tmp/ipykernel_33842/3259959042.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('https://raw.githubusercontent.com/pvbwashington-arch/311.-/refs/heads/main/311_Service_Requests_from_2019May.csv')

# %%
df.head()
# Out:
#    Unique Key   Created Date      Closed Date Agency  Complaint Type  \
# 0    42680103  5/1/2019 0:00  5/16/2019 21:45    DEP    Water System
# 1    42530481  5/1/2019 0:00    5/2/2019 0:00  DOHMH  Food Poisoning
# 2    42527619  5/1/2019 0:00   5/13/2019 0:00  DOHMH  Food Poisoning
# 3    42526597  5/1/2019 0:00    5/2/2019 0:00  DOHMH  Food Poisoning
# 4    42526595  5/1/2019 0:00    5/2/2019 0:00  DOHMH  Food Poisoning
#
#                 Location Type Incident Zip             Incident Address  \
# 0             Street/Sidewalk      11420.0            127-16 111 AVENUE
# 1  Restaurant/Bar/Deli/Bakery      10011.0         207 WEST   14 STREET
# 2  Restaurant/Bar/Deli/Bakery      10025.0                2664 BROADWAY
# 3  Restaurant/Bar/Deli/Bakery      11208.0  624 SOUTH CONDUIT BOULEVARD
# 4  Restaurant/Bar/Deli/Bakery      11106.0              31-91 21 STREET
#
#                Street Name Address Type  ...      Landmark Facility Type  \
# ...

# %% [markdown]
# 4.

# %%
print (df.shape)
print ("Rows:", df.shape[0])
print ("Columns:", df.shape[1])
print (df.dtypes)
# Out:
# (69637, 21)
# Rows: 69637
# Columns: 21
# Unique Key                  int64
# Created Date               object
# Closed Date                object
# Agency                     object
# Complaint Type             object
# Location Type              object
# Incident Zip               object
# Incident Address           object
# Street Name                object
# Address Type               object
# City                       object
# Landmark                   object
# Facility Type              object
# Status                     object
# Due Date                   object
# Resolution Description     object
# BBL                       float64
# Borough                    object
# Latitude                  float64
# Longitude                 float64
# Location                   object
# dtype: object

# %% [markdown]
# 5.

# %%
print (df.describe)
# Out:
# <bound method NDFrame.describe of        Unique Key    Created Date      Closed Date Agency  Complaint Type  \
# 0        42680103   5/1/2019 0:00  5/16/2019 21:45    DEP    Water System
# 1        42530481   5/1/2019 0:00    5/2/2019 0:00  DOHMH  Food Poisoning
# 2        42527619   5/1/2019 0:00   5/13/2019 0:00  DOHMH  Food Poisoning
# 3        42526597   5/1/2019 0:00    5/2/2019 0:00  DOHMH  Food Poisoning
# 4        42526595   5/1/2019 0:00    5/2/2019 0:00  DOHMH  Food Poisoning
# ...           ...             ...              ...    ...             ...
# 69632    42634163  5/10/2019 0:00   5/10/2019 0:00  DOHMH  Food Poisoning
# 69633    42624568  5/10/2019 0:00   5/16/2019 0:00  DOHMH  Standing Water
# 69634    42638781  5/10/2019 0:00  5/10/2019 13:00  DOHMH  Food Poisoning
# 69635    42637637  5/10/2019 0:00  5/10/2019 12:54  DOHMH  Food Poisoning
# 69636    42637636  5/10/2019 0:00  5/10/2019 12:53  DOHMH  Food Poisoning
#
# ...

# %% [markdown]
# 6.

# %%
print (df.isnull().sum().sum())
# Out:
# 231655

# %% [markdown]
# 7.

# %%
print (df.isnull().sum())
# Out:
# Unique Key                    0
# Created Date                  0
# Closed Date                5011
# Agency                        0
# Complaint Type                0
# Location Type             15659
# Incident Zip               2248
# Incident Address          10604
# Street Name               10605
# Address Type               1330
# City                       2221
# Landmark                  69621
# Facility Type             45556
# Status                        0
# Due Date                  36798
# Resolution Description     6058
# BBL                       13935
# Borough                       0
# Latitude                   4003
# Longitude                  4003
# Location                   4003
# dtype: int64

# %% [markdown]
# 8.

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)
print(df.mean)
# Out:
# <bound method DataFrame.mean of        Unique Key    Created Date      Closed Date Agency  Complaint Type  \
# 0        42680103   5/1/2019 0:00  5/16/2019 21:45    DEP    Water System
# 1        42530481   5/1/2019 0:00    5/2/2019 0:00  DOHMH  Food Poisoning
# 2        42527619   5/1/2019 0:00   5/13/2019 0:00  DOHMH  Food Poisoning
# 3        42526597   5/1/2019 0:00    5/2/2019 0:00  DOHMH  Food Poisoning
# 4        42526595   5/1/2019 0:00    5/2/2019 0:00  DOHMH  Food Poisoning
# ...           ...             ...              ...    ...             ...
# 69632    42634163  5/10/2019 0:00   5/10/2019 0:00  DOHMH  Food Poisoning
# 69633    42624568  5/10/2019 0:00   5/16/2019 0:00  DOHMH  Standing Water
# 69634    42638781  5/10/2019 0:00  5/10/2019 13:00  DOHMH  Food Poisoning
# 69635    42637637  5/10/2019 0:00  5/10/2019 12:54  DOHMH  Food Poisoning
# 69636    42637636  5/10/2019 0:00  5/10/2019 12:53  DOHMH  Food Poisoning
#
# ...

# %% [markdown]
# 9.

# %%
print(df.isnull().sum())
print("Total missing values after cleaning:", df.isnull().sum().sum())
# Out:
# Unique Key                0
# Created Date              0
# Closed Date               0
# Agency                    0
# Complaint Type            0
# Location Type             0
# Incident Zip              0
# Incident Address          0
# Street Name               0
# Address Type              0
# City                      0
# Landmark                  0
# Facility Type             0
# Status                    0
# Due Date                  0
# Resolution Description    0
# BBL                       0
# Borough                   0
# Latitude                  0
# Longitude                 0
# Location                  0
# dtype: int64
# Total missing values after cleaning: 0

# %% [markdown]
# 10

# %%
filtered_df = df[df['Complaint Type'] == 'Noise']
print(filtered_df.head())
# Out:
#     Unique Key   Created Date     Closed Date Agency Complaint Type  \
# 11    42524126  5/1/2019 0:00   5/3/2019 1:45    DEP          Noise
# 24    42524125  5/1/2019 0:04  5/8/2019 20:00    DEP          Noise
# 37    42525163  5/1/2019 0:09  5/1/2019 14:01    DEP          Noise
# 50    42530241  5/1/2019 0:12  5/1/2019 14:02    DEP          Noise
# 58    42530240  5/1/2019 0:15  5/1/2019 14:02    DEP          Noise
#
#       Location Type Incident Zip         Incident Address       Street Name  \
# 11  Street/Sidewalk      11226.0     601 MARLBOROUGH ROAD  MARLBOROUGH ROAD
# 24  Street/Sidewalk      10475.0        3563 ROPES AVENUE      ROPES AVENUE
# 37  Street/Sidewalk      10003.0  78-15 PARSONS BOULEVARD          BROADWAY
# 50  Street/Sidewalk      10009.0     361 EAST   10 STREET  EAST   10 STREET
# 58  Street/Sidewalk      10009.0     389 EAST   10 STREET  EAST   10 STREET
#
#     Address Type  ...      Landmark Facility Type  Status         Due Date  \
# ...

# %% [markdown]
# 11.

# %%
df['Status'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Complaint Status Distribution')
plt.ylabel('')
plt.show()

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Unique Key'}>,
#         <Axes: title={'center': 'BBL'}>],
#        [<Axes: title={'center': 'Latitude'}>,
#         <Axes: title={'center': 'Longitude'}>]], dtype=object)

# %%
df.plot('Status')
# Out:
# <Axes: xlabel='Status'>
